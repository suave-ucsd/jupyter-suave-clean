# %% [markdown]
# <h1><span style="color:red">Generate a SuAVE survey from the UN SDG database</span></h1>
#
# This Jupyter Notebook is designed to access SDG database and let users select variables and years to add to the survey file for visual analysis.
#
# You can execute cells in sequence (by clicking 'Run' above, or pressing Shift-Enter).
# The source of the SDG database is: Statistics Division, Department of Economic and Social Affairs, United Nations.
# The database can be downloaded from https://unstats.un.org/sdgs/indicators/database/
#
# Definitions of indicators are available at the same page. The current version is October 10, 2018

# %% [markdown]
# ## 1. Retrieve survey parameters from the URL

# %%
# %%javascript
# function getQueryStringValue (key)
# {
#     return unescape(window.location.search.replace(new RegExp("^(?:.*[&\\?]" + escape(key).replace(/[\.\+\*]/g, "\\$&") + "(?:\\=([^&]*))?)?.*$", "i"), "$1"));
# }
# IPython.notebook.kernel.execute("survey_url='".concat(getQueryStringValue("surveyurl")).concat("'"));
# IPython.notebook.kernel.execute("views='".concat(getQueryStringValue("views")).concat("'"));
# IPython.notebook.kernel.execute("view='".concat(getQueryStringValue("view")).concat("'"));
# IPython.notebook.kernel.execute("user='".concat(getQueryStringValue("user")).concat("'"));
# IPython.notebook.kernel.execute("csv_file='".concat(getQueryStringValue("csv")).concat("'"));
# IPython.notebook.kernel.execute("dzc_file='".concat(getQueryStringValue("dzc")).concat("'"));
# IPython.notebook.kernel.execute("params='".concat(getQueryStringValue("params")).concat("'"));
# IPython.notebook.kernel.execute("active_object='".concat(getQueryStringValue("activeobject")).concat("'"));
# IPython.notebook.kernel.execute("full_notebook_url='" + window.location + "'");

# %%
import pandas as pd
import xlrd
import csv
import urllib.request
import dropbox
import os
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import io
from collections import OrderedDict
import numpy as np
import re
import requests
from IPython.display import Markdown, display

def printmd(string):
    display(Markdown(string))

# %% [markdown]
# ## 2. Access local version of the UN SDG Database

# %%
file_names = []
file_directory = "/lib-nfs/largedatasets"
for file in os.listdir(file_directory):
    if file.endswith('.csv'):
        file_names.append(os.path.join(file_directory, file))
    
def f(file_name):
    return file_name
print('The source data file should contain fields named TimePeriod, SeriesCode, Indicator, and GeoAreaCode.') 
print('GeoAreaCode values will be matched with "UN Code" values in the survey file (this can be changed below).')
print('Select the source data file:')
fileName = interact(f, file_name=file_names)
# Out:
# The source data file should contain fields named TimePeriod, SeriesCode, Indicator, and GeoAreaCode.
# GeoAreaCode values will be matched with "UN Code" values in the survey file (this can be changed below).
# Select the source data file:
# interactive(children=(Dropdown(description='file_name', options=('/lib-nfs/largedatasets/SDG_all_2018.csv',), …

# %% [markdown]
# ## 3. Prepare to query the database

# %%
new_csv_file = fileName.widget.result

df = pd.read_csv(new_csv_file, low_memory=False)

time_periods = OrderedDict()
time_periods_list = sorted(list(set(list(df['TimePeriod']))))
for i in range(0, len(time_periods_list)):
    time_periods[str(time_periods_list[i])] = int(time_periods_list[i])


series_codes = []
for i in range(0, len(df['SeriesCode'])):
#     series_codes.append(df['SeriesCode'][i] + "-" + df['Indicator'][i])
    series_codes.append(df['Indicator'][i] + "-" + df['SeriesCode'][i])

series_codes = sorted(list(set(series_codes)))

# %% [markdown]
# ## 4. Select years of data to retrieve
#
# Use Shift or Ctrl to select multiple years

# %%
def g(TimePeriod):
    return TimePeriod

time_period_widget = interact(g, TimePeriod=widgets.SelectMultiple(options=time_periods))
# Out:
# interactive(children=(SelectMultiple(description='TimePeriod', options=OrderedDict([('2000', 2000), ('2001', 2…

# %% [markdown]
# ## 5. Select data series to retrieve
#
# Use Shift or Ctrl to select multiple series

# %%
def h(SeriesCode):
    return SeriesCode

series_code_widget = interact(h, SeriesCode=widgets.SelectMultiple(options=series_codes))
# Out:
# interactive(children=(SelectMultiple(description='SeriesCode', options=('1.5.1-VC_DSR_AFFCT', '1.5.1-VC_DSR_DA…

# %% [markdown]
# ## 6. Read the SuAVE survey file with base SDG data

# %%
old_csv_path = "../../temp_csvs"
old_csv = os.path.join(old_csv_path, csv_file)
old_df = pd.read_csv(old_csv, encoding='windows-1252')
# if that fails, try without encoding:
# old_df = pd.read_csv(old_csv)
print(df)
# Out:
#         Goal Target Indicator     SeriesCode  \
# 0          1    1.5     1.5.3  SG_DSR_LEGREG
# 1          1    1.5     1.5.3  SG_DSR_LEGREG
# 2          1    1.5     1.5.3  SG_DSR_LEGREG
# 3          1    1.5     1.5.3  SG_DSR_LEGREG
# 4          1    1.5     1.5.3  SG_DSR_LEGREG
# 5          1    1.5     1.5.3  SG_DSR_LEGREG
# 6          1    1.5     1.5.3  SG_DSR_LEGREG
# 7          1    1.5     1.5.3  SG_DSR_LEGREG
# 8          1    1.5     1.5.3  SG_DSR_LEGREG
# 9          1    1.5     1.5.3  SG_DSR_LEGREG
# 10         1    1.5     1.5.3  SG_DSR_LEGREG
# 11         1    1.5     1.5.3  SG_DSR_LEGREG
# 12         1    1.5     1.5.3  SG_DSR_LEGREG
# 13         1    1.5     1.5.3  SG_DSR_LEGREG
# 14         1    1.5     1.5.3  SG_DSR_LEGREG
# 15         1    1.5     1.5.3  SG_DSR_LEGREG
# 16         1    1.5     1.5.3  SG_DSR_LEGREG
# 17         1    1.5     1.5.3  SG_DSR_LEGREG
# 18         1    1.5     1.5.3  SG_DSR_LEGREG
# 19         1    1.5     1.5.3  SG_DSR_LEGREG
# 20         1    1.5     1.5.3  SG_DSR_LEGREG
# 21         1    1.5     1.5.3  SG_DSR_LEGREG
# 22         1    1.5     1.5.3  SG_DSR_LEGREG
# 23         1    1.5     1.5.3  SG_DSR_LEGREG
# 24         1    1.5     1.5.3  SG_DSR_LEGREG
# 25         1    1.5     1.5.3  SG_DSR_LEGREG
# 26         1    1.5     1.5.3  SG_DSR_LEGREG
# 27         1    1.5     1.5.3  SG_DSR_LEGREG
# 28         1    1.5     1.5.3  SG_DSR_LEGREG
# 29         1    1.5     1.5.3  SG_DSR_LEGREG
# ...      ...    ...       ...            ...
# 900192    15   15.b    15.b.1    DC_ODA_BDVL
# 900193    15   15.b    15.b.1    DC_ODA_BDVL
# 900194    15   15.b    15.b.1    DC_ODA_BDVL
# 900195    15   15.b    15.b.1    DC_ODA_BDVL
# 900196    15   15.b    15.b.1    DC_ODA_BDVL
# 900197    15   15.b    15.b.1    DC_ODA_BDVL
# 900198    15   15.b    15.b.1    DC_ODA_BDVL
# 900199    15   15.b    15.b.1    DC_ODA_BDVL
# 900200    15   15.b    15.b.1    DC_ODA_BDVL
# 900201    15   15.b    15.b.1    DC_ODA_BDVL
# 900202    15   15.b    15.b.1    DC_ODA_BDVL
# 900203    15   15.b    15.b.1    DC_ODA_BDVL
# 900204    15   15.b    15.b.1    DC_ODA_BDVL
# 900205    15   15.b    15.b.1    DC_ODA_BDVL
# 900206    15   15.b    15.b.1    DC_ODA_BDVL
# 900207    15   15.b    15.b.1    DC_ODA_BDVL
# 900208    15   15.b    15.b.1    DC_ODA_BDVL
# 900209    15   15.b    15.b.1    DC_ODA_BDVL
# 900210    15   15.b    15.b.1    DC_ODA_BDVL
# 900211    15   15.b    15.b.1    DC_ODA_BDVL
# 900212    15   15.b    15.b.1    DC_ODA_BDVL
# 900213    15   15.b    15.b.1    DC_ODA_BDVL
# 900214    15   15.b    15.b.1    DC_ODA_BDVL
# 900215    15   15.b    15.b.1    DC_ODA_BDVL
# 900216    15   15.b    15.b.1    DC_ODA_BDVL
# 900217    15   15.b    15.b.1    DC_ODA_BDVL
# 900218    15   15.b    15.b.1    DC_ODA_BDVL
# 900219    15   15.b    15.b.1    DC_ODA_BDVL
# 900220    15   15.b    15.b.1    DC_ODA_BDVL
# 900221    15   15.b    15.b.1    DC_ODA_BDVL
#
#                                         SeriesDescription  GeoAreaCode  \
# 0       Countries with legislative and/or regulatory p...            4
# 1       Countries with legislative and/or regulatory p...            4
# 2       Countries with legislative and/or regulatory p...           12
# 3       Countries with legislative and/or regulatory p...           32
# 4       Countries with legislative and/or regulatory p...           36
# 5       Countries with legislative and/or regulatory p...           36
# 6       Countries with legislative and/or regulatory p...           40
# 7       Countries with legislative and/or regulatory p...           48
# 8       Countries with legislative and/or regulatory p...           50
# 9       Countries with legislative and/or regulatory p...           50
# 10      Countries with legislative and/or regulatory p...           51
# 11      Countries with legislative and/or regulatory p...           52
# 12      Countries with legislative and/or regulatory p...           64
# 13      Countries with legislative and/or regulatory p...           64
# 14      Countries with legislative and/or regulatory p...           68
# 15      Countries with legislative and/or regulatory p...           76
# 16      Countries with legislative and/or regulatory p...           92
# 17      Countries with legislative and/or regulatory p...          100
# 18      Countries with legislative and/or regulatory p...          100
# 19      Countries with legislative and/or regulatory p...          108
# 20      Countries with legislative and/or regulatory p...          112
# 21      Countries with legislative and/or regulatory p...          112
# 22      Countries with legislative and/or regulatory p...          120
# 23      Countries with legislative and/or regulatory p...          124
# 24      Countries with legislative and/or regulatory p...          132
# 25      Countries with legislative and/or regulatory p...          144
# 26      Countries with legislative and/or regulatory p...          144
# 27      Countries with legislative and/or regulatory p...          152
# 28      Countries with legislative and/or regulatory p...          156
# 29      Countries with legislative and/or regulatory p...          170
# ...                                                   ...          ...
# 900192  Total official development assistance for biod...          887
# 900193  Total official development assistance for biod...          887
# 900194  Total official development assistance for biod...          887
# 900195  Total official development assistance for biod...          887
# 900196  Total official development assistance for biod...          887
# 900197  Total official development assistance for biod...          887
# 900198  Total official development assistance for biod...          887
# 900199  Total official development assistance for biod...          887
# 900200  Total official development assistance for biod...          887
# 900201  Total official development assistance for biod...          887
# 900202  Total official development assistance for biod...          887
# 900203  Total official development assistance for biod...          887
# 900204  Total official development assistance for biod...          887
# 900205  Total official development assistance for biod...          887
# 900206  Total official development assistance for biod...          887
# 900207  Total official development assistance for biod...          894
# 900208  Total official development assistance for biod...          894
# 900209  Total official development assistance for biod...          894
# 900210  Total official development assistance for biod...          894
# 900211  Total official development assistance for biod...          894
# 900212  Total official development assistance for biod...          894
# 900213  Total official development assistance for biod...          894
# 900214  Total official development assistance for biod...          894
# 900215  Total official development assistance for biod...          894
# 900216  Total official development assistance for biod...          894
# 900217  Total official development assistance for biod...          894
# 900218  Total official development assistance for biod...          894
# 900219  Total official development assistance for biod...          894
# 900220  Total official development assistance for biod...          894
# 900221  Total official development assistance for biod...          894
#
#                              GeoAreaName  TimePeriod     Value Time_Detail  \
# 0                            Afghanistan        2013         1        2013
# 1                            Afghanistan        2015         1        2015
# 2                                Algeria        2013         1        2013
# 3                              Argentina        2015         1        2015
# 4                              Australia        2013         1        2013
# 5                              Australia        2015         1        2015
# 6                                Austria        2015         1        2015
# 7                                Bahrain        2013         1        2013
# 8                             Bangladesh        2013         1        2013
# 9                             Bangladesh        2015         1        2015
# 10                               Armenia        2013         1        2013
# 11                              Barbados        2013         1        2013
# 12                                Bhutan        2013         1        2013
# 13                                Bhutan        2015         1        2015
# 14      Bolivia (Plurinational State of)        2013         1        2013
# 15                                Brazil        2013         1        2013
# 16                British Virgin Islands        2013         1        2013
# 17                              Bulgaria        2013         1        2013
# 18                              Bulgaria        2015         1        2015
# 19                               Burundi        2015         1        2015
# 20                               Belarus        2013         1        2013
# 21                               Belarus        2015         1        2015
# 22                              Cameroon        2015         1        2015
# 23                                Canada        2013         1        2013
# 24                            Cabo Verde        2015         1        2015
# 25                             Sri Lanka        2013         1        2013
# 26                             Sri Lanka        2015         1        2015
# 27                                 Chile        2013         1        2013
# 28                                 China        2013         1        2013
# 29                              Colombia        2013         1        2013
# ...                                  ...         ...       ...         ...
# 900192                             Yemen        2002   5.04375        2002
# 900193                             Yemen        2003   0.53038        2003
# 900194                             Yemen        2004   0.13301        2004
# 900195                             Yemen        2005   2.52882        2005
# 900196                             Yemen        2006   1.21271        2006
# 900197                             Yemen        2007   6.69305        2007
# 900198                             Yemen        2008   1.23524        2008
# 900199                             Yemen        2009   0.99257        2009
# 900200                             Yemen        2010  13.77027        2010
# 900201                             Yemen        2011   7.81834        2011
# 900202                             Yemen        2012   0.25571        2012
# 900203                             Yemen        2013   1.24776        2013
# 900204                             Yemen        2014   5.08165        2014
# 900205                             Yemen        2015   3.93172        2015
# 900206                             Yemen        2016   1.82379        2016
# 900207                            Zambia        2002   6.96317        2002
# 900208                            Zambia        2003  28.52968        2003
# 900209                            Zambia        2004  18.81558        2004
# 900210                            Zambia        2005  34.58026        2005
# 900211                            Zambia        2006  24.79218        2006
# 900212                            Zambia        2007  13.89594        2007
# 900213                            Zambia        2008  28.59456        2008
# 900214                            Zambia        2009  10.31225        2009
# 900215                            Zambia        2010  14.81737        2010
# 900216                            Zambia        2011  23.59393        2011
# 900217                            Zambia        2012  46.69386        2012
# 900218                            Zambia        2013  48.63264        2013
# 900219                            Zambia        2014  46.40471        2014
# 900220                            Zambia        2015  50.79423        2015
# 900221                            Zambia        2016  23.70201        2016
#
#               ...        [Location] [Migratory status]  \
# 0             ...               NaN                NaN
# 1             ...               NaN                NaN
# 2             ...               NaN                NaN
# 3             ...               NaN                NaN
# 4             ...               NaN                NaN
# 5             ...               NaN                NaN
# 6             ...               NaN                NaN
# 7             ...               NaN                NaN
# 8             ...               NaN                NaN
# 9             ...               NaN                NaN
# 10            ...               NaN                NaN
# 11            ...               NaN                NaN
# 12            ...               NaN                NaN
# 13            ...               NaN                NaN
# 14            ...               NaN                NaN
# 15            ...               NaN                NaN
# 16            ...               NaN                NaN
# 17            ...               NaN                NaN
# 18            ...               NaN                NaN
# 19            ...               NaN                NaN
# 20            ...               NaN                NaN
# 21            ...               NaN                NaN
# 22            ...               NaN                NaN
# 23            ...               NaN                NaN
# 24            ...               NaN                NaN
# 25            ...               NaN                NaN
# 26            ...               NaN                NaN
# 27            ...               NaN                NaN
# 28            ...               NaN                NaN
# 29            ...               NaN                NaN
# ...           ...               ...                ...
# 900192        ...               NaN                NaN
# 900193        ...               NaN                NaN
# 900194        ...               NaN                NaN
# 900195        ...               NaN                NaN
# 900196        ...               NaN                NaN
# 900197        ...               NaN                NaN
# 900198        ...               NaN                NaN
# 900199        ...               NaN                NaN
# 900200        ...               NaN                NaN
# 900201        ...               NaN                NaN
# 900202        ...               NaN                NaN
# 900203        ...               NaN                NaN
# 900204        ...               NaN                NaN
# 900205        ...               NaN                NaN
# 900206        ...               NaN                NaN
# 900207        ...               NaN                NaN
# 900208        ...               NaN                NaN
# 900209        ...               NaN                NaN
# 900210        ...               NaN                NaN
# 900211        ...               NaN                NaN
# 900212        ...               NaN                NaN
# 900213        ...               NaN                NaN
# 900214        ...               NaN                NaN
# 900215        ...               NaN                NaN
# 900216        ...               NaN                NaN
# 900217        ...               NaN                NaN
# 900218        ...               NaN                NaN
# 900219        ...               NaN                NaN
# 900220        ...               NaN                NaN
# 900221        ...               NaN                NaN
#
#        [Mode of transportation] [Name of non-communicable disease] [Quantile]  \
# 0                           NaN                                NaN        NaN
# 1                           NaN                                NaN        NaN
# 2                           NaN                                NaN        NaN
# 3                           NaN                                NaN        NaN
# 4                           NaN                                NaN        NaN
# 5                           NaN                                NaN        NaN
# 6                           NaN                                NaN        NaN
# 7                           NaN                                NaN        NaN
# 8                           NaN                                NaN        NaN
# 9                           NaN                                NaN        NaN
# 10                          NaN                                NaN        NaN
# 11                          NaN                                NaN        NaN
# 12                          NaN                                NaN        NaN
# 13                          NaN                                NaN        NaN
# 14                          NaN                                NaN        NaN
# 15                          NaN                                NaN        NaN
# 16                          NaN                                NaN        NaN
# 17                          NaN                                NaN        NaN
# 18                          NaN                                NaN        NaN
# 19                          NaN                                NaN        NaN
# 20                          NaN                                NaN        NaN
# 21                          NaN                                NaN        NaN
# 22                          NaN                                NaN        NaN
# 23                          NaN                                NaN        NaN
# 24                          NaN                                NaN        NaN
# 25                          NaN                                NaN        NaN
# 26                          NaN                                NaN        NaN
# 27                          NaN                                NaN        NaN
# 28                          NaN                                NaN        NaN
# 29                          NaN                                NaN        NaN
# ...                         ...                                ...        ...
# 900192                      NaN                                NaN        NaN
# 900193                      NaN                                NaN        NaN
# 900194                      NaN                                NaN        NaN
# 900195                      NaN                                NaN        NaN
# 900196                      NaN                                NaN        NaN
# 900197                      NaN                                NaN        NaN
# 900198                      NaN                                NaN        NaN
# 900199                      NaN                                NaN        NaN
# 900200                      NaN                                NaN        NaN
# 900201                      NaN                                NaN        NaN
# 900202                      NaN                                NaN        NaN
# 900203                      NaN                                NaN        NaN
# 900204                      NaN                                NaN        NaN
# 900205                      NaN                                NaN        NaN
# 900206                      NaN                                NaN        NaN
# 900207                      NaN                                NaN        NaN
# 900208                      NaN                                NaN        NaN
# 900209                      NaN                                NaN        NaN
# 900210                      NaN                                NaN        NaN
# 900211                      NaN                                NaN        NaN
# 900212                      NaN                                NaN        NaN
# 900213                      NaN                                NaN        NaN
# 900214                      NaN                                NaN        NaN
# 900215                      NaN                                NaN        NaN
# 900216                      NaN                                NaN        NaN
# 900217                      NaN                                NaN        NaN
# 900218                      NaN                                NaN        NaN
# 900219                      NaN                                NaN        NaN
# 900220                      NaN                                NaN        NaN
# 900221                      NaN                                NaN        NaN
#
#        [Reporting Type] [Sex] [Type of mobile technology]  \
# 0                     G   NaN                         NaN
# 1                     G   NaN                         NaN
# 2                     G   NaN                         NaN
# 3                     G   NaN                         NaN
# 4                     G   NaN                         NaN
# 5                     G   NaN                         NaN
# 6                     G   NaN                         NaN
# 7                     G   NaN                         NaN
# 8                     G   NaN                         NaN
# 9                     G   NaN                         NaN
# 10                    G   NaN                         NaN
# 11                    G   NaN                         NaN
# 12                    G   NaN                         NaN
# 13                    G   NaN                         NaN
# 14                    G   NaN                         NaN
# 15                    G   NaN                         NaN
# 16                    G   NaN                         NaN
# 17                    G   NaN                         NaN
# 18                    G   NaN                         NaN
# 19                    G   NaN                         NaN
# 20                    G   NaN                         NaN
# 21                    G   NaN                         NaN
# 22                    G   NaN                         NaN
# 23                    G   NaN                         NaN
# 24                    G   NaN                         NaN
# 25                    G   NaN                         NaN
# 26                    G   NaN                         NaN
# 27                    G   NaN                         NaN
# 28                    G   NaN                         NaN
# 29                    G   NaN                         NaN
# ...                 ...   ...                         ...
# 900192                G   NaN                         NaN
# 900193                G   NaN                         NaN
# 900194                G   NaN                         NaN
# 900195                G   NaN                         NaN
# 900196                G   NaN                         NaN
# 900197                G   NaN                         NaN
# 900198                G   NaN                         NaN
# 900199                G   NaN                         NaN
# 900200                G   NaN                         NaN
# 900201                G   NaN                         NaN
# 900202                G   NaN                         NaN
# 900203                G   NaN                         NaN
# 900204                G   NaN                         NaN
# 900205                G   NaN                         NaN
# 900206                G   NaN                         NaN
# 900207                G   NaN                         NaN
# 900208                G   NaN                         NaN
# 900209                G   NaN                         NaN
# 900210                G   NaN                         NaN
# 900211                G   NaN                         NaN
# 900212                G   NaN                         NaN
# 900213                G   NaN                         NaN
# 900214                G   NaN                         NaN
# 900215                G   NaN                         NaN
# 900216                G   NaN                         NaN
# 900217                G   NaN                         NaN
# 900218                G   NaN                         NaN
# 900219                G   NaN                         NaN
# 900220                G   NaN                         NaN
# 900221                G   NaN                         NaN
#
#        [Type of occupation] [Type of product]
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4                       NaN               NaN
# 5                       NaN               NaN
# 6                       NaN               NaN
# 7                       NaN               NaN
# 8                       NaN               NaN
# 9                       NaN               NaN
# 10                      NaN               NaN
# 11                      NaN               NaN
# 12                      NaN               NaN
# 13                      NaN               NaN
# 14                      NaN               NaN
# 15                      NaN               NaN
# 16                      NaN               NaN
# 17                      NaN               NaN
# 18                      NaN               NaN
# 19                      NaN               NaN
# 20                      NaN               NaN
# 21                      NaN               NaN
# 22                      NaN               NaN
# 23                      NaN               NaN
# 24                      NaN               NaN
# 25                      NaN               NaN
# 26                      NaN               NaN
# 27                      NaN               NaN
# 28                      NaN               NaN
# 29                      NaN               NaN
# ...                     ...               ...
# 900192                  NaN               NaN
# 900193                  NaN               NaN
# 900194                  NaN               NaN
# 900195                  NaN               NaN
# 900196                  NaN               NaN
# 900197                  NaN               NaN
# 900198                  NaN               NaN
# 900199                  NaN               NaN
# 900200                  NaN               NaN
# 900201                  NaN               NaN
# 900202                  NaN               NaN
# 900203                  NaN               NaN
# 900204                  NaN               NaN
# 900205                  NaN               NaN
# 900206                  NaN               NaN
# 900207                  NaN               NaN
# 900208                  NaN               NaN
# 900209                  NaN               NaN
# 900210                  NaN               NaN
# 900211                  NaN               NaN
# 900212                  NaN               NaN
# 900213                  NaN               NaN
# 900214                  NaN               NaN
# 900215                  NaN               NaN
# 900216                  NaN               NaN
# 900217                  NaN               NaN
# 900218                  NaN               NaN
# 900219                  NaN               NaN
# 900220                  NaN               NaN
# 900221                  NaN               NaN
#
# [900222 rows x 31 columns]

# %% [markdown]
# ## 7. Add the newly selected data series to the base SDG data

# %%
series_code = series_code_widget.widget.result
time_period = time_period_widget.widget.result

for i in range(0, len(series_code)):
    for j in range(0, len(time_period)):
        series_code_array = series_code[i].split("-")
        series_code_0 = series_code_array[0]
        series_code_1 = series_code_array[1]
            
        rows = df.loc[(df['TimePeriod'] == time_period[j]) & 
                          (df['SeriesCode'] == series_code_1) &
                          (df['Indicator'] == series_code_0)]
        
        if (not rows.empty):
        
#             new_col_name = series_code[i] + "-" + str(time_period[j])
            new_col_name = series_code_0 + "-" + series_code_1 +"-" + str(time_period[j])+"#number"
            old_df[new_col_name] = np.nan
        
            for k in range(0, len(rows.index)):
                
                geo_code = rows.iloc[k]['GeoAreaCode']
                value = rows.iloc[k]['Value']
                
# IMPORTANT: depending on the survey version, you may need to specify a field
# to match country numeric IDs in the UN SDG database
# In the 2015 version of the SDG survey in SuAVE, this field is 'UN Code#hidden' 
# In the 2018 version of the SDG survey in SuAVE, this field is 'ISO3166N3#hidden' 
# To switch, comment one of the two lines below, uncomment the other

#                 curr_row = old_df.loc[old_df['UN Code#hidden'] == geo_code]
                curr_row = old_df.loc[old_df['ISO3166N3#hidden'] == geo_code]
                if (not curr_row.empty):
                    
                    curr_index = curr_row.index[0]
                
                    old_df.at[curr_index, new_col_name] = value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ISO3166N3#hidden'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-23232241dde1> in <module>()
#      30
#      31 #                 curr_row = old_df.loc[old_df['UN Code#hidden'] == geo_code]
# ---> 32                 curr_row = old_df.loc[old_df['ISO3166N3#hidden'] == geo_code]
#      33                 if (not curr_row.empty):
#      34
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ISO3166N3#hidden'

# %% [markdown]
# ## 8. Save the new version of CSV file, and give a name to new survey

# %%
#Get file path
path = "../../temp_csvs"

# new file name
new_file =  csv_file[:-4] + '_v1.csv'
new_file_path = os.path.join(path, new_file)
old_df.to_csv(os.path.join(path, new_file))

# %%
#Input survey name

from IPython.display import display
input_text = widgets.Text()
output_text = widgets.Text()

def bind_input_to_output(sender):
    output_text.value = input_text.value

# Tell the text input widget to call bind_input_to_output() on submit
input_text.on_submit(bind_input_to_output)

printmd("<b><span style='color:red'>Input survey name here, press Enter, and then run the next cell:</span></b>")
# Display input text box widget for input
display(input_text)

display(output_text)
# Out:
# New survey with the selected SDG indicators will be named:
# Text(value='ilyaj_SDG18_Geo_v1')
# Text(value='ilyaj_SDG18_Geo_v1')

# %%
#Print survey name
survey_name = output_text.value
printmd("<b><span style='color:red'>Survey Name is: </span></b>" + survey_name)

# %% [markdown]
# ## 9. Generate the survey and create survey URL

# %%
referer = survey_url.split("/main")[0] +"/"
upload_url = referer + "uploadCSV"
new_survey_url_base = survey_url.split(user)[0]

import requests
import re
csv = {"file": open(new_file, "rb")}
upload_data = {
    'name': input_text.value,
    'dzc': dzc_file,
    'user':user
}
headers = {
    'User-Agent': 'suave user agent',
    'referer': referer
}

r = requests.post(upload_url, files=csv, data=upload_data, headers=headers)

if r.status_code == 200:
    printmd("<b><span style='color:red'>New survey created successfully</span></b>")
    regex = re.compile('[^0-9a-zA-Z_]')
    s_url = survey_name
    s_url =  regex.sub('_', s_url)

    url = new_survey_url_base + user + "_" + input_text.value + ".csv" + "&views=" + views + "&view=" + view
    print(url)
    printmd("<b><span style='color:red'>Click the URL to open the new survey</span></b>")
else:
    printmd("<b><span style='color:red'>Error creating new survey. Check if a survey with this name already exists.</span></b>")
    printmd("<b><span style='color:red'>Reason: </span></b>"+ str(r.status_code) + " " + r.reason)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7f51ec4b5084> in <module>()
#       1 upload_data = {'name': input_text.value, 'dzc': dzc_file, 'user':user}
#       2 files = {"file": open(new_file_path, "rb")}
# ----> 3 r = request.post(upload_url, files=files, data=upload_data)
#       4 print(r.status_code, r.reason)
#       5
#
# NameError: name 'request' is not defined
